# %% [markdown]
# $$
# \bigstar\;\diamond\;\bigstar\quad\boxed{\sigma_{\omega}\sigma}\quad\bigstar\;\diamond\;\bigstar
# $$

# %% [markdown]
# # 图 4.6

# %% [markdown]
# ## 理论

# %% [markdown]
# 我们需要处理的影响因素或许有成百上千个，但真正对输出结果起到关键作用的因素可能仅有少数几个。在试验设计相关文献中，该规律被称作效应稀疏原理。这种普遍存在的现象会对试验设计产生怎样的影响？

# %% [markdown]
# 考虑一个包含两个因子、4 次试验的试验设计，极大极小设计与极小极大设计如图 4.6 所示。本例中基于聚类的设计和极小极大设计完全一致。现假设因子 $x_2$ 无关紧要，即其对输出结果的影响可以忽略不计。那么对于左侧的设计而言，相当于在 $x_1=0$ 和 $x_1=1$ 两处各开展了两次试验；对于右侧设计，则是在 $x_1=0.25$ 和 $x_1=0.75$ 两处各重复两次试验。由于输出不存在误差，试验得到的输出数值将会完全相同。这一点在开展试验前就能预判，也就是说，重复开展这两组试验纯属浪费时间。倘若 $x_1$ 无影响、仅有 $x_2$ 起作用，也会出现相同的问题。这类不理想的情形在实际应用中极易出现，我们该如何规避？

# %% [markdown]
# ## 实践

# %% [markdown]
# 创建画布宽 20 英寸、高 10 英寸，将画布分为 1x2。依据点集
#
# $$
# (0,0)
# $$
#
# $$
# (0,1)
# $$
#
# $$
# (1,0)
# $$
#
# $$
# (1,1)
# $$
#
# 创建观测点矩阵 D。绘制 D 的散点图，其中点型为 16，大小为 4，不显示边框，颜色为 blue，x\y 轴范围均为 c(-.1,1.1)，x 轴标注为 expression(x[1])，y 轴标注为 expression(x[2])，大小为 2，标题为“极大极小设计”，大小为 3。叠加投影点，其中 x 轴上的投影点的横坐标与 D 的的横坐标相同，纵坐标为 -0.15，颜色为 2，点型为 16，大小为 4。加投影点，其中 y 轴上的投影点的纵坐标与 D 的的纵坐标相同，横坐标为 -0.15，颜色为 2，点型为 16，大小为 4。叠加箭头，其中箭头为
#
# $$
# (0,0)\to(0,-0.125)
# $$
#
# $$
# (1,0)\to(1,-0.125)
# $$
#
# $$
# (0,1)\to(0,0.875)
# $$
#
# $$
# (1,1)\to(1,0.875)
# $$
#
# $$
# (0,0)\to(-0.125,0)
# $$
#
# $$
# (0,1)\to(-0.125,1)
# $$
#
# $$
# (1,0)\to(0.875,0)
# $$
#
# $$
# (1,1)\to(0.875,1)
# $$
#
# 线宽为 2，线型为 2。

# %% [markdown]
# 依据点集
#
# $$
# (0.25,0.25)
# $$
#
# $$
# (0.25,0.75)
# $$
#
# $$
# (0.75,0.25)
# $$
#
# $$
# (0.75,0.75)
# $$
#
# 创建观测点矩阵 D。绘制 D 的散点图，其中点型为 16，大小为 4，不显示边框，颜色为 blue，x\y 轴范围均为 c(-.1,1.1)，x 轴标注为 expression(x[1])，y 轴标注为 expression(x[2])，大小为 2，标题为“极小极大设计”，大小为 3。叠加投影点，其中 x 轴上的投影点的横坐标与 D 的的横坐标相同，纵坐标为 -0.15，颜色为 2，点型为 16，大小为 4。加投影点，其中 y 轴上的投影点的纵坐标与 D 的的纵坐标相同，横坐标为 -0.15，颜色为 2，点型为 16，大小为 4。叠加箭头，其中箭头为
#
# $$
# (0.25,0.25)\to(0.25,0.125)
# $$
#
# $$
# (0.75,0.25)\to(0.75,0.125)
# $$
#
# $$
# (0.25,0.75)\to(0.25,0.625)
# $$
#
# $$
# (0.75,0.75)\to(0.75,0.625)
# $$
#
# $$
# (0.25,0.25)\to(0.125,0.25)
# $$
#
# $$
# (0.25,0.75)\to(0.125,0.75)
# $$
#
# $$
# (0.75,0.25)\to(0.625,0.25)
# $$
#
# $$
# (0.75,0.75)\to(0.625,0.75)
# $$
#
# 线宽为 2，线型为 2。将画布还原回 1x1。

# %%
options(repr.plot.width=20,repr.plot.height=10)
par(mfrow=c(1,2))
D=matrix(c(0,0,0,1,1,0,1,1),nrow=4,ncol=2,byrow=TRUE)
plot(D,pch=16,cex=4,bty="n",col="blue",xlim=c(-.1,1.1),ylim=c(-.1,1.1),xlab=expression(x[1]),ylab=expression(x[2]),cex.lab=2,main="极大极小设计",cex.main=3)
points(cbind(D[,1],-.15),col=2,pch=16,cex=4)
points(cbind(-.15,D[,2]),col=2,pch=16,cex=4)
arrows(0,0,0,-.125,lwd=2,lty=2)
arrows(1,0,1,-.125,lwd=2,lty=2)
arrows(0,1,0,.875,lwd=2,lty=2)
arrows(1,1,1,.875,lwd=2,lty=2)
arrows(0,0,-.125,0,lwd=2,lty=2)
arrows(0,1,-.125,1,lwd=2,lty=2)
arrows(1,0,.875,0,lwd=2,lty=2)
arrows(1,1,.875,1,lwd=2,lty=2)

D=matrix(c(0.25,0.25,.25,.75,.75,.25,.75,.75),nrow=4,ncol=2,byrow=TRUE)
plot(D,pch=16,cex=4,bty="n",col="blue",xlim=c(-.1,1.1),ylim=c(-.1,1.1),xlab=expression(x[1]),ylab=expression(x[2]),cex.lab=2,main="极小极大设计",cex.main=3)
points(cbind(D[,1],-.15),col=2,pch=16,cex=4)
points(cbind(-.15,D[,2]),col=2,pch=16,cex=4)
arrows(.25,.25,.25,.125,lwd=2,lty=2)
arrows(.75,.25,.75,.125,lwd=2,lty=2)
arrows(.25,.75,.25,.625,lwd=2,lty=2)
arrows(.75,.75,.75,.625,lwd=2,lty=2)
arrows(.25,.25,.125,.25,lwd=2,lty=2)
arrows(.25,.75,.125,.75,lwd=2,lty=2)
arrows(.75,.25,.625,.25,lwd=2,lty=2)
arrows(.75,.75,.625,.75,lwd=2,lty=2)
par(mfrow=c(1,1))
# Out:
# Plot with title "极小极大设计"

# %% [markdown]
# $$
# \bigstar\;\diamond\;\bigstar\quad\boxed{\sigma_{\omega}\sigma}\quad\bigstar\;\diamond\;\bigstar
# $$
