# %% [markdown]
# ### 2.1.3 克里金

# %% [markdown]
# 克里金法是一种多元插值技术，以克里格（1951）命名，马瑟荣（1963）通过开创性研究将其发展应用于地质统计学领域。该方法的起源可参阅克雷西（1990）的著作。克雷西（1993）探讨了克里金法在空间统计问题中的应用，斯坦（1999）阐述了其理论基础。萨克斯等人（1989）将这一技术引入计算机实验领域。

# %% [markdown]
# 克里金法的核心思想是将确定性函数 $h(\boldsymbol{x})$ 视作随机过程 $Y(\boldsymbol{x})$ 的一次实现。设该随机过程均值恒为 $\mu$，协方差函数为 $K(\boldsymbol{u},\boldsymbol{v})=\text{cov}\{Y(\boldsymbol{u}),Y(\boldsymbol{v})\}$。对于二阶平稳随机过程，其协方差函数可写为：
#
# $$
# K(\boldsymbol{u},\boldsymbol{v}) = \tau^2 R(\boldsymbol{u}-\boldsymbol{v})
# $$
#
# 式中 $\tau^2$ 为方差，$R(\cdot)$ 为相关函数。我们可以选用哪些相关函数呢？由于 $cor\{Y(\boldsymbol{u}),Y(\boldsymbol{u})\}=1$，必然满足 $R(\boldsymbol{0})=1$；同时 $cor\{Y(\boldsymbol{u}),Y(\boldsymbol{v})\}=cor\{Y(\boldsymbol{v}),Y(\boldsymbol{u})\}$，因此 $R(\boldsymbol{u}-\boldsymbol{v})=R(\boldsymbol{v}-\boldsymbol{u})$，说明 $R(\cdot)$ 必须是偶函数。最后，对任意向量 $\boldsymbol{c}$ 均满足 $var\{\boldsymbol{c}'\boldsymbol{Y}\}\ge0$，等价于 $\boldsymbol{c}'\boldsymbol{R}\boldsymbol{c}\ge0$，这就要求 $R(\cdot)$ 为半正定函数。满足上述条件的函数有很多，式 (2.8) 中的高斯函数便是其中之一。不过并非一定要选用径向（各向同性）函数。实际上，为各个输入变量设置不同的长度尺度参数往往具备显著优势。由矩阵代数结论可知：正定矩阵的哈达玛积仍为正定矩阵（法斯豪尔，2007，第 30 页），由此可推得正定函数的乘积同样具备正定性。据此定义高斯乘积相关函数：
#
# $$
# R(\Delta)=\prod_{i=1}^{p}e^{-\Delta_i^2/\theta_i^2}=e^{-\sum_{i=1}^{p}\Delta_i^2/\theta_i^2}
# \tag{2.11}
# $$
#
# 表 2.1 列出了几种常用一维相关函数。多维相关函数有两种构造方式：一是仿照式 (2.11) 将一维相关函数相乘；二是将自变量差值 $\Delta$ 替换为加权欧几里得范数：$\|\Delta\|_\theta=\sqrt{\sum_{i=1}^{p}(\Delta_i/\theta_i)^2}$。相关函数的选取决定了随机过程的光滑程度。例如，高斯相关函数对应的样本路径无穷阶可微，而指数相关函数对应的样本路径处处不可微。详细内容可参阅拉斯穆森与威廉姆斯（2006，第 4 章）以及法斯豪尔与麦考特（2015，第 3 章）。

# %% [markdown]
# > **表 2.1** 若干常用相关函数。

# %% [markdown]
# 名称 | 相关函数$R(\Delta)$ | 参数条件
# :----: | :----: | :----:
# 高斯型 | $\mathrm{e}^{-\Delta^2/\theta^2}$ | $\theta > 0$
# 指数型 | $\mathrm{e}^{-\|\Delta\|/\theta}$ | $\theta > 0$
# 幂指数型 | $\mathrm{e}^{-(\|\Delta\|/\theta)^\alpha}$ | $\theta > 0,\ 0 < \alpha \le 2$
# 3/2 阶马特恩函数 | $\left(1+\sqrt{3}\frac{\left\|\Delta\right\|}{\theta}\right)\mathrm{e}^{-\sqrt{3}\|\Delta\|/\theta}$ | $\theta > 0$
# 5/2 阶马特恩函数 | $\left(1+\sqrt{5}\frac{\left\|\Delta\right\|}{\theta}+\frac53\frac{\Delta^2}{\theta^2}\right)\mathrm{e}^{-\sqrt{5}\|\Delta\|/\theta}$ | $\theta > 0$
# 有理二次型 | $\left(1+\frac{\Delta^2}{\theta^2}\right)^{-\alpha}$ | $\theta > 0,\ \alpha > 0$

# %% [markdown]
# 现有数据集 $\{(\boldsymbol{x}_i, y_i)\}_{i=1}^n$，我们可以构造线性预测器：
#
# $$
# \hat{y}(\boldsymbol{x}) = \boldsymbol{a}(\boldsymbol{x})^\prime \boldsymbol{y}
# $$
#
# 并通过最小化预测均方误差来求解最优线性预测器：
#
# $$
# MSE(\boldsymbol{x}) = E\left\{\boldsymbol{a}(\boldsymbol{x})^\prime \boldsymbol{Y} - Y(\boldsymbol{x})\right\}^2 \tag{2.12}
# $$
#
# 式中的期望是针对随机过程求取。采用频率学派视角时，我们将观测数据向量 $\boldsymbol{y}$ 替换为其随机形式 $\boldsymbol{Y} = \left(Y(\boldsymbol{x}_1),\dots,Y(\boldsymbol{x}_n)\right)^\prime$。若满足
#
# $$
# E\left\{\boldsymbol{a}(\boldsymbol{x})^\prime \boldsymbol{Y}\right\} = \mu,\quad \forall x
# $$
#
# 则该线性预测器为无偏预测器。
#
# 由于 $E(\boldsymbol{Y}) = \mu\boldsymbol{1}$（$\boldsymbol{1}$ 为由 $n$ 个 1 构成的向量），无偏条件可简化为：
#
# $$
# \boldsymbol{a}(\boldsymbol{x})^\prime \boldsymbol{1} = 1
# $$
#
# 此时均方误差可推导为：
#
# $$
# \begin{aligned}
# MSE(\boldsymbol{x}) &= var\left\{\boldsymbol{a}(\boldsymbol{x})^\prime \boldsymbol{Y} - Y(\boldsymbol{x})\right\} \\
# &= \boldsymbol{a}(\boldsymbol{x})^\prime var\{\boldsymbol{Y}\}\boldsymbol{a}(\boldsymbol{x}) - 2\boldsymbol{a}(\boldsymbol{x})^\prime cov\{\boldsymbol{Y},Y(\boldsymbol{x})\} + \tau^2 \\
# &= \tau^2\boldsymbol{a}(\boldsymbol{x})^\prime \boldsymbol{R}\boldsymbol{a}(\boldsymbol{x}) - 2\tau^2\boldsymbol{a}(\boldsymbol{x})^\prime \boldsymbol{r}(\boldsymbol{x}) + \tau^2
# \end{aligned}
# $$
#
# 其中矩阵 $\boldsymbol{R}$ 与向量 $\boldsymbol{r}(\boldsymbol{x})$ 定义如下：
#
# $$
# \boldsymbol{R}=
# \begin{bmatrix}
# 1 & & \cdots & & \\ \\
# \vdots & & R(\boldsymbol{x}_{i}-\boldsymbol{x}_{j}) & & \vdots \\ \\
# & & \cdots & & 1
# \end{bmatrix}
# ,\quad\boldsymbol{r}(\boldsymbol{x})=
# \begin{bmatrix}
# \vdots \\ \\ R(\boldsymbol{x}-\boldsymbol{x}_i) \\ \\ \vdots
# \end{bmatrix}
# \tag{2.13}
# $$

# %% [markdown]
# 因此该优化问题写作

# %% [markdown]
# $$\begin{align*}&\min_{\boldsymbol{a}(\boldsymbol{x})}\boldsymbol{a}(\boldsymbol{x})'\boldsymbol{R}\boldsymbol{a}(\boldsymbol{x})-2\boldsymbol{a}(\boldsymbol{x})'\boldsymbol{r}(\boldsymbol{x})+1\\&\text{s.t.}\;\boldsymbol{a}(\boldsymbol{x})'\boldsymbol{1}=1\end{align*}$$

# %% [markdown]
# 可采用拉格朗日乘子法求解(为简化书写省略自变量$\boldsymbol{x}$):

# %% [markdown]
# $$\min L=\boldsymbol{a}'\boldsymbol{R}\boldsymbol{a}-2\boldsymbol{a}'\boldsymbol{r}+1+2\lambda(\boldsymbol{a}'\boldsymbol{1}-1)$$

# %% [markdown]
# 将$L$对$\boldsymbol{a}$求偏导并令导数等于$0$,可得

# %% [markdown]
# $$\frac{\partial L}{\partial\boldsymbol{a}}=2\boldsymbol{R}\boldsymbol{a}-2\boldsymbol{r}+2\lambda\boldsymbol{1}=0$$

# %% [markdown]
# 整理得到$\boldsymbol{a}=\boldsymbol{R}^{-1}(\boldsymbol{r}-\lambda\boldsymbol{1})$.将其代入约束条件并解出$\lambda$,得$\lambda=(\boldsymbol{r}'\boldsymbol{R}^{-1}\boldsymbol{1}-1)/\boldsymbol{1}'\boldsymbol{R}^{-1}\boldsymbol{1}$.于是

# %% [markdown]
# $$\widehat{\boldsymbol{a}}=\boldsymbol{R}^{-1}\boldsymbol{r}-\frac{\boldsymbol{r}'\boldsymbol{R}^{-1}\boldsymbol{1}-1}{\boldsymbol{1}'\boldsymbol{R}^{-1}\boldsymbol{1}}\cdot\boldsymbol{R}^{-1}\boldsymbol{1}$$

# %% [markdown]
# 由此得到最优线性无偏预测(BLUP):

# %% [markdown]
# $$\begin{align*}\widehat{y}(\boldsymbol{x})&=\widehat{\boldsymbol{a}}(\boldsymbol{x})'\boldsymbol{y}\\&=\boldsymbol{r}(\boldsymbol{x})'\boldsymbol{R}^{-1}\boldsymbol{y}-\frac{\boldsymbol{r}(\boldsymbol{x})'\boldsymbol{R}^{-1}\boldsymbol{1}-1}{\boldsymbol{1}'\boldsymbol{R}^{-1}\boldsymbol{1}}\cdot\boldsymbol{1}'\boldsymbol{R}^{-1}\boldsymbol{y}\\&=\widehat{\mu}+\boldsymbol{r}(\boldsymbol{x})'\boldsymbol{R}^{-1}(\boldsymbol{y}-\widehat{\mu}\boldsymbol{1})\tag{2.14}\end{align*}$$

# %% [markdown]
# 其中

# %% [markdown]
# $$\widehat{\mu}=\frac{\boldsymbol{1}'\boldsymbol{R}^{-1}\boldsymbol{y}}{\boldsymbol{1}'\boldsymbol{R}^{-1}\boldsymbol{1}}\tag{2.15}$$

# %% [markdown]
# 易看出式(2.15)给出的$\mu$估计量是广义最小二乘(GLS)估计,对应假设$\mathbb{E}(\boldsymbol{y})=\mu\boldsymbol{1},\;\mathrm{Var}(\boldsymbol{y})=\tau^{2}\boldsymbol{R}$的情形.因此式(2.14)的预测过程可拆解为三步:(i)利用广义最小二乘由数据估计均值$\mu$;(ii)计算残差$\boldsymbol{y}-\widehat{\mu}\boldsymbol{1}$;(iii)对残差做插值,再将插值结果叠加到均值估计$\widehat{\mu}$上.

# %% [markdown]
# 式(2.14)对应的预测器称为普通克里金法.注意

# %% [markdown]
# $$\begin{align*}\boldsymbol{I}=\boldsymbol{R}^{-1}\boldsymbol{R}&=\boldsymbol{R}^{-1}\begin{bmatrix}\boldsymbol{r}(\boldsymbol{x}_{1})&\cdots&\boldsymbol{r}(\boldsymbol{x}_{i})&\cdots&\boldsymbol{r}(\boldsymbol{x}_{n})\end{bmatrix}\\&=\begin{bmatrix}\boldsymbol{R}^{-1}\boldsymbol{r}(\boldsymbol{x}_{1})&\cdots&\boldsymbol{R}^{-1}\boldsymbol{r}(\boldsymbol{x}_{i})&\cdots&\boldsymbol{R}^{-1}\boldsymbol{r}(\boldsymbol{x}_{n})\end{bmatrix}\end{align*}$$

# %% [markdown]
# 由此可得,对$i=1,\dots,n$有$\boldsymbol{R}^{-1}\boldsymbol{r}(\boldsymbol{x}_{i})=\boldsymbol{I}_{i}$,其中$\boldsymbol{I}_{i}$为单位矩阵的第$i$列.因此

# %% [markdown]
# $$\begin{align*}\widehat{y}(\boldsymbol{x}_{i})&=\widehat{\mu}+\boldsymbol{I}_{i}'(\boldsymbol{y}-\widehat{\mu}\boldsymbol{1})\\&=\widehat{\mu}+(y_{i}-\widehat{\mu})=y_{i},\;\forall i\end{align*}$$

# %% [markdown]
# 这说明普通克里金预测器具备插值特性.

# %% [markdown]
# 将普通克里金预测式代入预测均方误差表达式并化简,可得

# %% [markdown]
# $$\mathrm{MSE}(\boldsymbol{x})=\tau^{2}\left(1-\boldsymbol{r}(\boldsymbol{x})'\boldsymbol{R}^{-1}\boldsymbol{r}(\boldsymbol{x})+\frac{(\boldsymbol{r}(\boldsymbol{x})'\boldsymbol{R}^{-1}\boldsymbol{1}-1)^{2}}{\boldsymbol{1}'\boldsymbol{R}^{-1}\boldsymbol{1}}\right)\tag{2.16}$$

# %% [markdown]
# 该式可量化预测结果的不确定性.由于$\boldsymbol{R}^{-1}\boldsymbol{r}(\boldsymbol{x}_{i})=\boldsymbol{I}_{i}$且$R(\boldsymbol{0})=1$,有

# %% [markdown]
# $$\begin{align*}\mathrm{MSE}(\boldsymbol{x}_{i})&=\tau^{2}\left(1-\boldsymbol{r}(\boldsymbol{x}_{i})'\boldsymbol{I}_{i}+\frac{(\boldsymbol{I}_{i}'\boldsymbol{1}-1)^{2}}{\boldsymbol{1}'\boldsymbol{R}^{-1}\boldsymbol{1}}\right)\\&=\tau^{2}\left(1-R(\boldsymbol{x}_{i}-\boldsymbol{x}_{i})+\frac{(1-1)^{2}}{\boldsymbol{1}'\boldsymbol{R}^{-1}\boldsymbol{1}}\right)=0,\;\forall i\end{align*}$$

# %% [markdown]
# 这表明在已观测采样点处不存在预测不确定性.该结论符合直观,因为这些位置的观测数据无测量误差.

# %% [markdown]
# 再次考虑式(2.1)中的一维算例,设计点集$D=\{(i-1)/(n-1)\}_{i=1}^{n}$,取$n=10$.进行预测前仍需给定相关参数$\theta$,可沿用2.1.2节介绍的交叉验证方法;若对随机过程的分布做出假设,也可采用极大似然估计方法,下一节将详细介绍该思路.本节暂取此前通过最小化均方交叉验证误差得到的参数估计值$\widehat{\theta}=0.08$.图2.4给出普通克里金预测曲线,同时附带$\pm2\sqrt{\mathrm{MSE}(x)}$构成的95%预测区间(系数$2$基于正态分布假设推导,下一节会进一步说明).该预测结果与径向基插值的输出相近,但普通克里金能够额外给出预测不确定性.符合预期的是:预测点越靠近观测点,不确定性越小;预测点离观测点越远,不确定性越高.

# %% [markdown]
# >**图2.4** 一维算例的普通克里金结果,阴影区域为95%预测区间

# %%
#图2.4

options(repr.plot.width=10,repr.plot.height=10)
library(DiceKriging)
f=function(x)sin(10*pi*x)/(1+64*(x-.25)^2)+x^2
test=seq(0,1,length=301)
true=f(test)
n=10
D=((1:n)-1)/(n-1)
y=f(D)

# 拟合普通克里金模型(固定 theta, 未知 mu 和 tau^2)
km.model=km(design=as.matrix(D),response=y,covtype="gauss",coef.cov=0.08,coef.var=1)
# 预测
pred.obj=predict(km.model,as.matrix(test),type="SK")
pred=pred.obj$mean
MSE=pred.obj$sd^2
low=pred-2*sqrt(pmax(MSE,0))
up=pred+2*sqrt(pmax(MSE,0))

plot(test,true,type="n",xlab="x",ylab="y",ylim=c(min(true)-.25,max(true)+.25),main="普通克里金插值",cex.main=3,cex.lab=2,cex.axis=2)
polygon(c(test,rev(test)),c(low,rev(up)),col="pink",border=NA)
points(cbind(D,y),pch=16,cex=2,col="blue")
lines(test,true,lty=2,lwd=3)
lines(test,pred,col=3,lwd=3)
legend(.5,-.3,legend=c("真实值","预测值"),lty=c(2,1),col=c(1,3),lwd=c(3,3),bty="n",cex=2)
# Out:
# Plot with title "普通克里金插值"
